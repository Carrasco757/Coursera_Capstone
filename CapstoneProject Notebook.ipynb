# %% [markdown]
# <h1>This notebook will be mainly used for the Capstone Project</h1>

# %% [markdown]
# <p><strong>Welcome!</strong> I'll first import the pandas library and then, the Numpy library</p>

# %% [markdown]
# <h2 id="pandas">Importing <code>Pandas</code></h2>

# %%
# Dependency needed to install file 

# !pip install xlrd

# %%
# Import required library

import pandas as pd

# %% [markdown]
# <h2 id="data">Importing Numpy</h2>

# %%
import numpy as np

print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# <hr>

# %% [markdown]
# <p>Copyright &copy; 2018 IBM Developer Skills Network. This notebook and its source code are released under the terms of the <a href="https://cognitiveclass.ai/mit-license/">MIT License</a>.</p>
